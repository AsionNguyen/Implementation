# %%
import fft

# %%
n = 8
d = euler_phi(n)
K.<x> = CyclotomicField(n)
f = K.random_element()

# %%
coeffs_f=f.list(); coeffs_f
# Out:
# [9/2, -1, 36, -10/3]

# %%
f_fft = fft.fft(coeffs_f); f_fft
# Out:
# [(6.149915822768609+32.935870614858295j),
#  (2.850084177231391+39.064129385141705j),
#  (6.149915822768609-32.935870614858295j),
#  (2.850084177231391-39.064129385141705j)]

# %%
ff = fft.ifft(f_fft);ff
# Out:
# [0.6666666666666665,
#  2.0000000000000013,
#  0.9999999999999998,
#  0.0,
#  -0.2999999999999998,
#  1.1102230246251565e-16,
#  2.5,
#  0.0]

# %%
fft.ifft(f_fft)

# %%
def ring(q, alpha):
    return q/alpha^2, alpha^2*q

n = 8
d = euler_phi(n)
q = 12289
alpha = 1.15
a,b = ring(q,alpha)

# %%
center = 2*sqrt((2*d+1)/48)
error = 2*alpha*sqrt(q*(2*d+1)/48)
new_ring = [a-center+error, b-center-error]; new_ring
# Out:
# [0.575000000000000*sqrt(36867) - 1/2*sqrt(3) + 9292.24952741021,
#  -0.575000000000000*sqrt(36867) - 1/2*sqrt(3) + 16252.2025000000]

# %%
def norm(x):
    return x*x.conjugate()

def is_in_ring(t, ring):
    norm = t[0]*t[0].conjugate()+t[1]*t[1].conjugate()
    if norm > ring[0] and norm < ring[1]:
        return True
    else:
        return False

def Is_in_ring(x, y, d, ring):
    for i in range(d):
        if is_in_ring([x[i],y[i]], ring) == False:
            return (i, False)
    return True

def sample_annulus(ring):
    a = ring[0]
    b = ring[1]
    T_r = RealDistribution('uniform', [sqrt(a), sqrt(b)])
    T_theta = RealDistribution('uniform', [0, 2*pi])
    
    r = T_r.get_random_element()
    theta = T_theta.get_random_element()
    x = r*cos(theta)
    y = r*sin(theta)
    
    mu = T_theta.get_random_element()
    f = abs(x)*exp(1j*mu)
    mu = T_theta.get_random_element()
    g = abs(y)*exp(1j*mu)
    
    return f,g

# %%
'''Choose Fourier representations'''
F=[]; G=[]
dd = d/2
for _ in range(dd):
    f,g = sample_annulus(new_ring)
    F.append(f)
    G.append(g)

F2 = [F[i].conjugate() for i in range(dd)]
G2 = [G[i].conjugate() for i in range(dd)]

#FF = matrix(CC, d, 1, F+F2)
#GG = matrix(CC, d, 1, G+G2)

'''Integral Fourier inverse'''
#theoretically, f,g are real but they are complex in this computation
f = fft.ifft(F+F2)           
g = fft.ifft(G+G2)

# %%
x = F+F2; x
# Out:
# [-92.1598769464129 - 35.0165601557105*I,
#  -48.1041709743033 + 8.84292102689265*I,
#  -92.1598769464129 + 35.0165601557105*I,
#  -48.1041709743033 - 8.84292102689265*I]

# %%
x =[1, I, 1, -I]

# %%
fft.ifft(x)
# Out:
# [<built-in method real of sage.rings.complex_double.ComplexDoubleElement object at 0x18683a080>,
#  <built-in method real of sage.rings.complex_double.ComplexDoubleElement object at 0x186837740>,
#  <built-in method imag of sage.rings.complex_double.ComplexDoubleElement object at 0x18683a080>,
#  <built-in method imag of sage.rings.complex_double.ComplexDoubleElement object at 0x186837740>]

# %%
Is_in_ring(FF2,GG2,d,[a,b])

# %%
f[0]
# Out:
# <built-in method real of sage.rings.complex_mpfr.ComplexNumber object at 0x1866a2040>

# %%
#rounding f to ff (closest integral vector)
ff = [round(f.numpy()[i][0].real) for i in range(d)]
gg = [round(g.numpy()[i][0].real) for i in range(d)]
f2 = matrix(CC, d, 1, ff)
g2 = matrix(CC, d, 1, gg)
FF2 = fft.fft(f2)
GG2 = fft.fft(g2)

# %%
import fft_sage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/37/40t8n66d41b6jldvnttx32c40000gn/T/ipykernel_7906/3024021163.py in <cell line: 1>()
# ----> 1 import fft_sage
#
# ~/Programs/projects/python/falcon.py-master/fft_sage.py in <module>
#       9
#      10 from common import split, merge         # Import split and merge
# ---> 11 from fft_constants_sage import roots_dict    # Import constants useful for the FFT
#      12
#      13
#
# ~/Programs/projects/python/falcon.py-master/fft_constants_sage.py in <module>
#       9 The second root is the con*Iugates of the first one.
#      10 """
# ---> 11 phi4_roots = [1.00000000000000*I, -1.00000000000000*I]
#      12
#      13 """ The roots of phi_8 = x^4 + 1
#
# NameError: name 'I' is not defined

# %%
"""
Constants (complex roots of cyclotomic polynomials) for the NTT.
These were computed using scripts/generate_constants.sage.
If this module is loaded with fft_short, we only need the first half of each phi*_roots table.
"""


""" The roots of phi_4 = x^2 + 1
The second root is the con*Iugates of the first one.
"""
phi4_roots = [1.00000000000000*I, -1.00000000000000*I]

""" The roots of phi_8 = x^4 + 1
The second half of the roots are is the con*Iugates of the first half.
The root at index (2 * i + 1) is the negation of the root at index (2 * i).
"""
phi8_roots = [0.707106781186548 + 0.707106781186547*I,
              -0.707106781186548 - 0.707106781186547*I,
              0.707106781186548 - 0.707106781186547*I,
              -0.707106781186548 + 0.707106781186547*I]


""" The roots of phi_16 = x^8 + 1
The second half of the roots are is the con*Iugates of the first half.
The root at index (2 * i + 1) is the negation of the root at index (2 * i).
"""
phi16_roots = [0.923879532511287 + 0.382683432365090*I,
               -0.923879532511287 - 0.382683432365090*I,
               0.382683432365090 - 0.923879532511287*I,
               -0.382683432365090 + 0.923879532511287*I,
               0.923879532511287 - 0.382683432365090*I,
               -0.923879532511287 + 0.382683432365090*I,
               0.382683432365090 + 0.923879532511287*I,
               -0.382683432365090 - 0.923879532511287*I]


""" The roots of phi_32 = x^16 + 1
The second half of the roots are is the con*Iugates of the first half.
The root at index (2 * i + 1) is the negation of the root at index (2 * i).
"""
phi32_roots = [0.980785280403230 + 0.195090322016128*I,
               -0.980785280403230 - 0.195090322016128*I,
               0.195090322016128 - 0.980785280403230*I,
               -0.195090322016128 + 0.980785280403230*I,
               0.831469612302545 - 0.555570233019602*I,
               -0.831469612302545 + 0.555570233019602*I,
               0.555570233019602 + 0.831469612302545*I,
               -0.555570233019602 - 0.831469612302545*I,
               0.980785280403230 - 0.195090322016128*I,
               -0.980785280403230 + 0.195090322016128*I,
               0.195090322016128 + 0.980785280403230*I,
               -0.195090322016128 - 0.980785280403230*I,
               0.831469612302545 + 0.555570233019602*I,
               -0.831469612302545 - 0.555570233019602*I,
               0.555570233019602 - 0.831469612302545*I,
               -0.555570233019602 + 0.831469612302545*I]


""" The roots of phi_64 = x^32 + 1
The second half of the roots are is the con*Iugates of the first half.
The root at index (2 * i + 1) is the negation of the root at index (2 * i).
"""
phi64_roots = [0.995184726672197 + 0.0980171403295606*I,
               -0.995184726672197 - 0.0980171403295606*I,
               0.0980171403295606 - 0.995184726672197*I,
               -0.0980171403295606 + 0.995184726672197*I,
               0.773010453362737 - 0.634393284163646*I,
               -0.773010453362737 + 0.634393284163646*I,
               0.634393284163645 + 0.773010453362737*I,
               -0.634393284163645 - 0.773010453362737*I,
               0.956940335732209 - 0.290284677254462*I,
               -0.956940335732209 + 0.290284677254462*I,
               0.290284677254462 + 0.956940335732209*I,
               -0.290284677254462 - 0.956940335732209*I,
               0.881921264348355 + 0.471396736825998*I,
               -0.881921264348355 - 0.471396736825998*I,
               0.471396736825998 - 0.881921264348355*I,
               -0.471396736825998 + 0.881921264348355*I,
               0.995184726672197 - 0.0980171403295606*I,
               -0.995184726672197 + 0.0980171403295606*I,
               0.0980171403295606 + 0.995184726672197*I,
               -0.0980171403295606 - 0.995184726672197*I,
               0.773010453362737 + 0.634393284163646*I,
               -0.773010453362737 - 0.634393284163646*I,
               0.634393284163645 - 0.773010453362737*I,
               -0.634393284163645 + 0.773010453362737*I,
               0.956940335732209 + 0.290284677254462*I,
               -0.956940335732209 - 0.290284677254462*I,
               0.290284677254462 - 0.956940335732209*I,
               -0.290284677254462 + 0.956940335732209*I,
               0.881921264348355 - 0.471396736825998*I,
               -0.881921264348355 + 0.471396736825998*I,
               0.471396736825998 + 0.881921264348355*I,
               -0.471396736825998 - 0.881921264348355*I]


""" The roots of phi_128 = x^64 + 1
The second half of the roots are is the con*Iugates of the first half.
The root at index (2 * i + 1) is the negation of the root at index (2 * i).
"""
phi128_roots = [0.998795456205172 + 0.0490676743274180*I,
                -0.998795456205172 - 0.0490676743274180*I,
                0.0490676743274180 - 0.998795456205172*I,
                -0.0490676743274180 + 0.998795456205172*I,
                0.740951125354959 - 0.671558954847018*I,
                -0.740951125354959 + 0.671558954847018*I,
                0.671558954847018 + 0.740951125354959*I,
                -0.671558954847018 - 0.740951125354959*I,
                0.941544065183021 - 0.336889853392220*I,
                -0.941544065183021 + 0.336889853392220*I,
                0.336889853392220 + 0.941544065183021*I,
                -0.336889853392220 - 0.941544065183021*I,
                0.903989293123443 + 0.427555093430282*I,
                -0.903989293123443 - 0.427555093430282*I,
                0.427555093430282 - 0.903989293123443*I,
                -0.427555093430282 + 0.903989293123443*I,
                0.989176509964781 - 0.146730474455362*I,
                -0.989176509964781 + 0.146730474455362*I,
                0.146730474455362 + 0.989176509964781*I,
                -0.146730474455362 - 0.989176509964781*I,
                0.803207531480645 + 0.595699304492433*I,
                -0.803207531480645 - 0.595699304492433*I,
                0.595699304492433 - 0.803207531480645*I,
                -0.595699304492433 + 0.803207531480645*I,
                0.219101240156870 + 0.975702130038529*I,
                -0.219101240156870 - 0.975702130038529*I,
                0.844853565249707 + 0.534997619887097*I,
                -0.844853565249707 - 0.534997619887097*I,
                0.534997619887097 - 0.844853565249707*I,
                -0.534997619887097 + 0.844853565249707*I,
                0.997290456678690 + 0.0735645635996674*I,
                -0.997290456678690 - 0.0735645635996674*I,
                0.0735645635996674 - 0.997290456678690*I,
                -0.0735645635996674 + 0.997290456678690*I,
                0.757208846506485 - 0.653172842953777*I,
                -0.757208846506485 + 0.653172842953777*I,
                0.653172842953777 + 0.757208846506485*I,
                -0.653172842953777 - 0.757208846506485*I,
                0.949528180593037 - 0.313681740398892*I,
                -0.949528180593037 + 0.313681740398892*I,
                0.313681740398892 + 0.949528180593037*I,
                -0.313681740398892 - 0.949528180593037*I,
                0.893224301195515 + 0.449611329654607*I,
                -0.893224301195515 - 0.449611329654607*I,
                0.449611329654607 - 0.893224301195515*I,
                -0.449611329654607 + 0.893224301195515*I,
                0.992479534598710 - 0.122410675199216*I,
                -0.992479534598710 + 0.122410675199216*I,
                0.122410675199216 + 0.992479534598710*I,
                -0.122410675199216 - 0.992479534598710*I,
                0.788346427626606 + 0.615231590580627*I,
                -0.788346427626606 - 0.615231590580627*I,
                0.615231590580627 - 0.788346427626606*I,
                -0.615231590580627 + 0.788346427626606*I,
                0.963776065795440 + 0.266712757474898*I,
                -0.963776065795440 - 0.266712757474898*I,
                0.266712757474898 - 0.963776065795440*I,
                -0.266712757474898 + 0.963776065795440*I,
                0.870086991108711 - 0.492898192229784*I,
                -0.870086991108711 + 0.492898192229784*I,
                0.492898192229784 + 0.870086991108711*I,
                -0.492898192229784 - 0.870086991108711*I]


""" The roots of phi_512 = x^256 + 1
The second half of the roots are is the con*Iugates of the first half.
The root at index (2 * i + 1) is the negation of the root at index (2 * i).
"""
phi512_roots = [0.999924701839145 + 0.0122715382857199*I,
                -0.999924701839145 - 0.0122715382857199*I,
                0.0122715382857199 - 0.999924701839145*I,
                -0.0122715382857199 + 0.999924701839145*I,
                0.715730825283819 - 0.698376249408973*I,
                -0.715730825283819 + 0.698376249408973*I,
                0.698376249408973 + 0.715730825283819*I,
                -0.698376249408973 - 0.715730825283819*I,
                0.928506080473216 - 0.371317193951837*I,
                -0.928506080473216 + 0.371317193951837*I,
                0.371317193951837 + 0.928506080473216*I,
                -0.371317193951837 - 0.928506080473216*I,
                0.919113851690058 + 0.393992040061048*I,
                -0.919113851690058 - 0.393992040061048*I,
                0.393992040061048 - 0.919113851690058*I,
                -0.393992040061048 + 0.919113851690058*I,
                0.983105487431216 - 0.183039887955141*I,
                -0.983105487431216 + 0.183039887955141*I,
                0.183039887955141 + 0.983105487431216*I,
                -0.183039887955141 - 0.983105487431216*I,
                0.824589302785025 + 0.565731810783613*I,
                -0.824589302785025 - 0.565731810783613*I,
                0.565731810783613 - 0.824589302785025*I,
                -0.565731810783613 + 0.824589302785025*I,
                0.978317370719628 + 0.207111376192219*I,
                -0.978317370719628 - 0.207111376192219*I,
                 -0.0674439195636641 + 0.997723066644192*I,
                 0.753186799043613 - 0.657806693297079*I,
                 -0.753186799043613 + 0.657806693297079*I,
                 0.657806693297079 + 0.753186799043613*I,
                 -0.657806693297079 - 0.753186799043613*I,
                 0.947585591017741 - 0.319502030816016*I,
                 -0.947585591017741 + 0.319502030816016*I,
                 0.319502030816016 + 0.947585591017741*I,
                 -0.319502030816016 - 0.947585591017741*I,
                 0.895966249756185 + 0.444122144570429*I,
                 -0.895966249756185 - 0.444122144570429*I,
                 0.444122144570429 - 0.895966249756185*I,
                 -0.444122144570429 + 0.895966249756185*I,
                 0.991709753669100 - 0.128498110793793*I,
                 -0.991709753669100 + 0.128498110793793*I,
                 0.128498110793793 + 0.991709753669100*I,
                 -0.128498110793793 - 0.991709753669100*I,
                 0.792106577300212 + 0.610382806276309*I,
                 -0.792106577300212 - 0.610382806276309*I,
                 0.610382806276309 - 0.792106577300212*I,
                 -0.610382806276309 + 0.792106577300212*I,
                 0.965394441697689 + 0.260794117915276*I,
                 -0.965394441697689 - 0.260794117915276*I,
                 0.260794117915276 - 0.965394441697689*I,
                 -0.260794117915276 + 0.965394441697689*I,
                 0.867046245515693 - 0.498227666972782*I,
                 -0.867046245515693 + 0.498227666972782*I,
                 0.498227666972782 + 0.867046245515693*I,
                 -0.498227666972782 - 0.867046245515693*I]


""" The roots of phi_2048 = x^1024 + 1
The second half of the roots are is the con*Iugates of the first half.
The root at index (2 * i + 1) is the negation of the root at index (2 * i).
"""
phi2048_roots = [0.999995293809576 + 0.00306795676296598*I,
                 -0.999995293809576 - 0.00306795676296598*I,
                 0.00306795676296598 - 0.999995293809576*I,
                 -0.00306795676296598 + 0.999995293809576*I,
                 0.709272826438866 - 0.704934080375905*I,
                 -0.709272826438866 + 0.704934080375905*I,
                 0.704934080375905 + 0.709272826438866*I,
                 -0.704934080375905 - 0.709272826438866*I,
                 0.925049240782678 - 0.379847208924051*I,
                 -0.925049240782678 + 0.379847208924051*I,
                 0.379847208924051 + 0.925049240782678*I,
                 -0.379847208924051 - 0.925049240782678*I,
                 0.922701128333879 + 0.385516053843919*I,
                 -0.922701128333879 - 0.385516053843919*I,
                 0.385516053843919 - 0.922701128333879*I,
                 -0.385516053843919 + 0.922701128333879*I,
                 0.981379193313755 - 0.192080397049892*I,
                 -0.981379193313755 + 0.192080397049892*I,
                 0.192080397049892 + 0.981379193313755*I,
                 -0.192080397049892 - 0.981379193313755*I,
                 0.829761233794523 + 0.558118531220556*I,
                 -0.829761233794523 - 0.558118531220556*I,
                 0.558118531220556 - 0.829761233794523*I,
                 -0.558118531220556 + 0.829761233794523*I,
                 0.980182135968117 + 0.198098410717954*I,
                 -0.980182135968117 - 0.198098410717954*I,
                 0.198098410717954 - 0.980182135968117*I,
                 -0.198098410717954 + 0.980182135968117*I,
                 0.833170164701913 - 0.553016705580028*I,
                 -0.833170164701913 + 0.553016705580028*I,
                 0.553016705580028 + 0.833170164701913*I,
                 -0.553016705580028 - 0.833170164701913*I,
                 -0.997511456140303 + 0.0705045733896139*I,
                 0.0705045733896139 + 0.997511456140303*I,
                 -0.0705045733896139 - 0.997511456140303*I,
                 0.755201376896537 + 0.655492852999615*I,
                 -0.755201376896537 - 0.655492852999615*I,
                 0.655492852999615 - 0.755201376896537*I,
                 -0.655492852999615 + 0.755201376896537*I,
                 0.948561349915730 + 0.316593375556166*I,
                 -0.948561349915730 - 0.316593375556166*I,
                 0.316593375556166 - 0.948561349915730*I,
                 -0.316593375556166 + 0.948561349915730*I,
                 0.894599485631383 - 0.446868840162374*I,
                 -0.894599485631383 + 0.446868840162374*I,
                 0.446868840162374 + 0.894599485631383*I,
                 -0.446868840162374 - 0.894599485631383*I,
                 0.992099313142192 + 0.125454983411546*I,
                 -0.992099313142192 - 0.125454983411546*I,
                 0.125454983411546 - 0.992099313142192*I,
                 -0.125454983411546 + 0.992099313142192*I,
                 0.790230221437310 - 0.612810082429410*I,
                 -0.790230221437310 + 0.612810082429410*I,
                 0.612810082429410 + 0.790230221437310*I,
                 -0.612810082429410 - 0.790230221437310*I,
                 0.964589793289813 - 0.263754678974831*I,
                 -0.964589793289813 + 0.263754678974831*I,
                 0.263754678974831 + 0.964589793289813*I,
                 -0.263754678974831 - 0.964589793289813*I,
                 0.868570705971341 + 0.495565261825772*I,
                 -0.868570705971341 - 0.495565261825772*I,
                 0.495565261825772 - 0.868570705971341*I,
                 -0.495565261825772 + 0.868570705971341*I,
                 0.999957644551964 - 0.00920375478205982*I,
                 -0.999957644551964 + 0.00920375478205982*I,
                 0.00920375478205982 + 0.999957644551964*I,
                 -0.00920375478205982 - 0.999957644551964*I,
                 0.713584868780794 + 0.700568793943248*I,
                 -0.713584868780794 - 0.700568793943248*I,
                 0.700568793943248 - 0.713584868780794*I,
                 -0.700568793943248 + 0.713584868780794*I,
                 0.927362525650401 + 0.374164062971458*I,
                 -0.927362525650401 - 0.374164062971458*I,
                 0.374164062971458 - 0.927362525650401*I,
                 -0.374164062971458 + 0.927362525650401*I,
                 0.920318276709110 - 0.391170384302254*I,
                 -0.920318276709110 + 0.391170384302254*I,
                 0.391170384302254 + 0.920318276709111*I,
                 -0.391170384302254 - 0.920318276709111*I,
                 0.982539302287441 + 0.186055151663447*I,
                 -0.982539302287441 - 0.186055151663447*I,
                 0.186055151663447 - 0.982539302287441*I,
                 -0.186055151663447 + 0.982539302287441*I,
                 0.826321062845664 - 0.563199344013834*I,
                 -0.826321062845664 + 0.563199344013834*I,
                 0.563199344013834 + 0.826321062845664*I,
                 -0.563199344013834 - 0.826321062845664*I,
                 0.978948175319062 - 0.204108966092817*I,
                 -0.978948175319062 + 0.204108966092817*I,
                 0.204108966092817 + 0.978948175319062*I,
                 -0.204108966092817 - 0.978948175319062*I,
                 0.836547727223512 + 0.547894059173100*I,
                 -0.836547727223512 - 0.547894059173100*I,
                 0.547894059173100 - 0.836547727223512*I,
                 -0.547894059173100 + 0.836547727223512*I,
                 0.996044700901252 + 0.0888535525825246*I,
                 -0.0766238613920315 - 0.997060070339483*I,
                 0.759209188978388 + 0.650846684996381*I,
                 -0.759209188978388 - 0.650846684996381*I,
                 0.650846684996381 - 0.759209188978388*I,
                 -0.650846684996381 + 0.759209188978388*I,
                 0.950486073949482 + 0.310767152749612*I,
                 -0.950486073949482 - 0.310767152749612*I,
                 0.310767152749612 - 0.950486073949482*I,
                 -0.310767152749612 + 0.950486073949482*I,
                 0.891840709392343 - 0.452349587233771*I,
                 -0.891840709392343 + 0.452349587233771*I,
                 0.452349587233771 + 0.891840709392343*I,
                 -0.452349587233771 - 0.891840709392343*I,
                 0.992850414459865 + 0.119365214810991*I,
                 -0.992850414459865 - 0.119365214810991*I,
                 0.119365214810991 - 0.992850414459865*I,
                 -0.119365214810991 + 0.992850414459865*I,
                 0.786455213599086 - 0.617647307937804*I,
                 -0.786455213599086 + 0.617647307937804*I,
                 0.617647307937804 + 0.786455213599086*I,
                 -0.617647307937804 - 0.786455213599086*I,
                 0.962953266873684 - 0.269668325572915*I,
                 -0.962953266873684 + 0.269668325572915*I,
                 0.269668325572915 + 0.962953266873684*I,
                 -0.269668325572915 - 0.962953266873684*I,
                 0.871595086655951 + 0.490226483288291*I,
                 -0.871595086655951 - 0.490226483288291*I,
                 0.490226483288291 - 0.871595086655951*I,
                 -0.490226483288291 + 0.871595086655951*I,
                 0.999618822495179 - 0.0276081457789657*I,
                 -0.999618822495179 + 0.0276081457789657*I,
                 0.0276081457789657 + 0.999618822495179*I,
                 -0.0276081457789657 - 0.999618822495179*I,
                 0.726359155084346 + 0.687315340891759*I,
                 -0.726359155084346 - 0.687315340891759*I,
                 0.687315340891759 - 0.726359155084346*I,
                 -0.687315340891759 + 0.726359155084346*I,
                 0.934092550404259 + 0.357030961233430*I,
                 -0.934092550404259 - 0.357030961233430*I,
                 0.357030961233430 - 0.934092550404259*I,
                 -0.357030961233430 + 0.934092550404259*I,
                 0.912962190428398 - 0.408044162864979*I,
                 -0.912962190428398 + 0.408044162864979*I,
                 0.408044162864979 + 0.912962190428398*I,
                 -0.408044162864979 - 0.912962190428398*I,
                 0.985797509167567 + 0.167938294974731*I,
                 -0.985797509167567 - 0.167938294974731*I,
                 0.167938294974731 - 0.985797509167567*I,
                 -0.167938294974731 + 0.985797509167567*I,
                 0.815814410806734 - 0.578313796411656*I,
                 -0.815814410806734 + 0.578313796411656*I,
                 0.578313796411656 + 0.815814410806734*I,
                 -0.578313796411656 - 0.815814410806734*I,
                 0.975025345066994 - 0.222093620973204*I,
                 -0.975025345066994 + 0.222093620973204*I,
                 0.222093620973204 + 0.975025345066994*I,
                 -0.222093620973204 - 0.975025345066994*I,
                 0.846490938774052 + 0.532403127877198*I,
                 -0.846490938774052 - 0.532403127877198*I,
                 0.532403127877198 - 0.846490938774052*I,
                 -0.532403127877198 + 0.846490938774052*I,
                 0.997511456140303 + 0.0705045733896139*I,
                 -0.997511456140303 - 0.0705045733896139*I,
                 0.0705045733896139 - 0.997511456140303*I,
                 -0.0705045733896139 + 0.997511456140303*I,
                 0.755201376896537 - 0.655492852999615*I,
                 -0.755201376896537 + 0.655492852999615*I,
                 0.655492852999615 + 0.755201376896537*I,
                 -0.655492852999615 - 0.755201376896537*I,
                 0.948561349915730 - 0.316593375556166*I,
                 -0.948561349915730 + 0.316593375556166*I,
                 0.316593375556166 + 0.948561349915730*I,
                 -0.316593375556166 - 0.948561349915730*I,
                 0.894599485631383 + 0.446868840162374*I,
                 -0.894599485631383 - 0.446868840162374*I,
                 0.446868840162374 - 0.894599485631383*I,
                 -0.446868840162374 + 0.894599485631383*I,
                 0.992099313142192 - 0.125454983411546*I,
                 -0.992099313142192 + 0.125454983411546*I,
                 0.125454983411546 + 0.992099313142192*I,
                 -0.125454983411546 - 0.992099313142192*I,
                 0.790230221437310 + 0.612810082429410*I,
                 -0.790230221437310 - 0.612810082429410*I,
                 0.612810082429410 - 0.790230221437310*I,
                 -0.612810082429410 + 0.790230221437310*I,
                 0.964589793289813 + 0.263754678974831*I,
                 -0.964589793289813 - 0.263754678974831*I,
                 0.263754678974831 - 0.964589793289813*I,
                 -0.263754678974831 + 0.964589793289813*I,
                 0.868570705971341 - 0.495565261825772*I,
                 -0.868570705971341 + 0.495565261825772*I,
                 0.495565261825772 + 0.868570705971341*I,
                 -0.495565261825772 - 0.868570705971341*I,
                 0.999957644551964 + 0.00920375478205982*I,
                 -0.999957644551964 - 0.00920375478205982*I,
                 0.00920375478205982 - 0.999957644551964*I,
                 -0.00920375478205982 + 0.999957644551964*I,
                 0.713584868780794 - 0.700568793943248*I,
                 -0.713584868780794 + 0.700568793943248*I,
                 0.700568793943248 + 0.713584868780794*I,
                 -0.700568793943248 - 0.713584868780794*I,
                 0.927362525650401 - 0.374164062971458*I,
                 -0.927362525650401 + 0.374164062971458*I,
                 0.374164062971458 + 0.927362525650401*I,
                 -0.374164062971458 - 0.927362525650401*I,
                 0.920318276709110 + 0.391170384302254*I,
                 -0.920318276709110 - 0.391170384302254*I,
                 0.391170384302254 - 0.920318276709111*I,
                 -0.391170384302254 + 0.920318276709111*I,
                 0.982539302287441 - 0.186055151663447*I,
                 -0.982539302287441 + 0.186055151663447*I,
                 0.186055151663447 + 0.982539302287441*I,
                 -0.186055151663447 - 0.982539302287441*I,
                 0.826321062845664 + 0.563199344013834*I,
                 -0.826321062845664 - 0.563199344013834*I,
                 0.563199344013834 - 0.826321062845664*I,
                 -0.563199344013834 + 0.826321062845664*I,
                 0.978948175319062 + 0.204108966092817*I,
                 -0.978948175319062 - 0.204108966092817*I,
                 0.204108966092817 - 0.978948175319062*I,
                 -0.204108966092817 + 0.978948175319062*I,
                 0.836547727223512 - 0.547894059173100*I,
                 -0.836547727223512 + 0.547894059173100*I,
                 0.547894059173100 + 0.836547727223512*I,
                 -0.547894059173100 - 0.836547727223512*I,
                 0.996044700901252 - 0.0888535525825246*I,
                 -0.996044700901252 + 0.0888535525825246*I,
                 0.0888535525825246 + 0.996044700901252*I,
                 -0.0888535525825246 - 0.996044700901252*I,
                 0.767138911935820 + 0.641481012808583*I,
                 -0.767138911935820 - 0.641481012808583*I,
                 0.641481012808583 - 0.767138911935820*I,
                 -0.641481012808583 + 0.767138911935820*I,
                 0.954228095109106 + 0.299079826308040*I,
                 -0.954228095109106 - 0.299079826308040*I,
                 0.299079826308040 - 0.954228095109106*I,
                 -0.299079826308040 + 0.954228095109106*I,
                 0.886222530148881 - 0.463259783551860*I,
                 -0.886222530148881 + 0.463259783551860*I,
                 0.463259783551860 + 0.886222530148881*I,
                 -0.463259783551860 - 0.886222530148881*I,
                 0.994240449453188 + 0.107172424956809*I,
                 -0.994240449453188 - 0.107172424956809*I,
                 0.107172424956809 - 0.994240449453188*I,
                 -0.107172424956809 + 0.994240449453188*I,
                 0.778816512381476 - 0.627251815495144*I,
                 -0.778816512381476 + 0.627251815495144*I,
                 0.627251815495144 + 0.778816512381476*I,
                 -0.627251815495144 - 0.778816512381476*I,
                 0.959571513081985 - 0.281464937925758*I,
                 -0.959571513081985 + 0.281464937925758*I,
                 0.281464937925758 + 0.959571513081985*I,
                 -0.281464937925758 - 0.959571513081985*I,
                 0.877545290207261 + 0.479493757660153*I,
                 -0.877545290207261 - 0.479493757660153*I,
                 0.479493757660153 - 0.877545290207261*I,
                 -0.479493757660153 + 0.877545290207261*I,
                 0.999204758618364 - 0.0398729275877398*I,
                 -0.999204758618364 + 0.0398729275877398*I,
                 0.0398729275877398 + 0.999204758618364*I,
                 -0.0398729275877398 - 0.999204758618364*I,
                 0.734738878095963 + 0.678350043129862*I,
                 -0.734738878095963 - 0.678350043129862*I,
                 0.678350043129861 - 0.734738878095963*I,
                 -0.678350043129861 + 0.734738878095963*I,
                 0.938403534063108 + 0.345541324963989*I,
                 -0.938403534063108 - 0.345541324963989*I,
                 0.345541324963989 - 0.938403534063108*I,
                 -0.345541324963989 + 0.938403534063108*I,
                 0.907886116487666 - 0.419216888363224*I,
                 -0.907886116487666 + 0.419216888363224*I,
                 0.419216888363224 + 0.907886116487666*I,
                 -0.419216888363224 - 0.907886116487666*I,
                 0.987784141644572 + 0.155828397654265*I,
                 -0.987784141644572 - 0.155828397654265*I,
                 0.155828397654265 - 0.987784141644572*I,
                 -0.155828397654265 + 0.987784141644572*I,
                 0.808656181588175 - 0.588281548222645*I,
                 -0.808656181588175 + 0.588281548222645*I,
                 0.588281548222645 + 0.808656181588175*I,
                 -0.588281548222645 - 0.808656181588175*I,
                 0.972226497078936 - 0.234041958583543*I,
                 -0.972226497078936 + 0.234041958583543*I,
                 0.234041958583543 + 0.972226497078936*I,
                 -0.234041958583543 - 0.972226497078936*I,
                 0.852960604930364 + 0.521975292937154*I,
                 -0.852960604930364 - 0.521975292937154*I,
                 0.521975292937154 - 0.852960604930364*I,
                 -0.521975292937154 + 0.852960604930364*I,
                 0.998301544933893 + 0.0582582645004358*I,
                 -0.998301544933893 - 0.0582582645004358*I,
                 0.0582582645004358 - 0.998301544933893*I,
                 -0.0582582645004358 + 0.998301544933893*I,
                 0.751165131909686 + 0.660114342067420*I,
                 -0.751165131909686 - 0.660114342067420*I,
                 0.660114342067420 - 0.751165131909686*I,
                 -0.660114342067420 + 0.751165131909686*I,
                 0.946600913083284 + 0.322407678801070*I,
                 -0.946600913083284 - 0.322407678801070*I,
                 0.322407678801070 - 0.946600913083284*I,
                 -0.322407678801070 + 0.946600913083284*I,
                 0.897324580705418 - 0.441371268731717*I,
                 -0.897324580705418 + 0.441371268731717*I,
                 0.441371268731717 + 0.897324580705418*I,
                 -0.441371268731717 - 0.897324580705418*I,
                 0.991310859846115 + 0.131540028702883*I,
                 -0.991310859846115 - 0.131540028702883*I,
                 0.131540028702883 - 0.991310859846115*I,
                 -0.131540028702883 + 0.991310859846115*I,
                 0.793975477554337 - 0.607949784967774*I,
                 -0.793975477554337 + 0.607949784967774*I,
                 0.607949784967774 + 0.793975477554337*I,
                 -0.607949784967774 - 0.793975477554337*I,
                 0.966190003445413 - 0.257831102162159*I,
                 -0.966190003445413 + 0.257831102162159*I,
                 0.257831102162159 + 0.966190003445413*I,
                 -0.257831102162159 - 0.966190003445413*I,
                 0.865513624090569 + 0.500885382611241*I,
                 -0.865513624090569 - 0.500885382611241*I,
                 0.500885382611241 - 0.865513624090569*I,
                 -0.500885382611241 + 0.865513624090569*I]


"""A dictionary of all the roots."""
roots_dict = {2: phi4_roots,
              4: phi8_roots,
              8: phi16_roots,
              16: phi32_roots,
              32: phi64_roots,
              64: phi128_roots,
              128: phi256_roots,
              256: phi512_roots,
              512: phi1024_roots,
              1024: phi2048_roots
              }

# %%
from common import split, merge

# %%
def split_fft(f_fft):
    """Split a polynomial f in two polynomials.

    Args:
        f: a polynomial

    Format: FFT

    Corresponds to algorithm 1 (splitfft_2) of Falcon's documentation.
    """
    n = len(f_fft)
    w = roots_dict[n]
    f0_fft = [0] * (n // 2)
    f1_fft = [0] * (n // 2)
    for i in range(n // 2):
        f0_fft[i] = 0.5 * (f_fft[2 * i] + f_fft[2 * i + 1])
        f1_fft[i] = 0.5 * (f_fft[2 * i] - f_fft[2 * i + 1]) * w[2 * i].conjugate()
    return [f0_fft, f1_fft]


def merge_fft(f_list_fft):
    """Merge two or three polynomials into a single polynomial f.

    Args:
        f_list: a list of polynomials

    Format: FFT

    Corresponds to algorithm 2 (mergefft_2) of Falcon's documentation.
    """
    f0_fft, f1_fft = f_list_fft
    n = 2 * len(f0_fft)
    w = roots_dict[n]
    f_fft = [0] * n
    for i in range(n // 2):
        f_fft[2 * i + 0] = f0_fft[i] + w[2 * i] * f1_fft[i]
        f_fft[2 * i + 1] = f0_fft[i] - w[2 * i] * f1_fft[i]
    return f_fft


def fft(f):
    """Compute the FFT of a polynomial mod (x ** n + 1).

    Args:
        f: a polynomial

    Format: input as coefficients, output as FFT
    """
    n = len(f)
    if (n > 2):
        f0, f1 = split(f)
        f0_fft = fft(f0)
        f1_fft = fft(f1)
        f_fft = merge_fft([f0_fft, f1_fft])
    elif (n == 2):
        f_fft = [0] * n
        f_fft[0] = f[0] + 1j * f[1]
        f_fft[1] = f[0] - 1j * f[1]
    return f_fft


def ifft(f_fft):
    """Compute the inverse FFT of a polynomial mod (x ** n + 1).

    Args:
        f: a FFT of a polynomial

    Format: input as FFT, output as coefficients
    """
    n = len(f_fft)
    if (n > 2):
        f0_fft, f1_fft = split_fft(f_fft)
        f0 = ifft(f0_fft)
        f1 = ifft(f1_fft)
        f = merge([f0, f1])
    elif (n == 2):
        f = [0] * n
        f[0] = f_fft[0].real()
        f[1] = f_fft[0].imag()
    return f

# %%
ifft([1,I,1, -I])
# Out:
# [0.500000000000000,
#  4.99600361081320e-16,
#  0.500000000000000,
#  -0.707106781186547]

# %%
def ring(q, alpha):
    return q/alpha^2, alpha^2*q

# %%
n = 256
d = euler_phi(n)
q = 12289
alpha = 1.15
a,b = ring(q,alpha)

# %%
a,b
# Out:
# (9292.24952741021, 16252.2025000000)

# %%
center = 2*sqrt((2*d+1)/48)
error = 2*alpha*sqrt(q*(2*d+1)/48)
new_ring = [a-center+error, b-center-error]; new_ring
# Out:
# [1.72500000000000*sqrt(233491) - 3/2*sqrt(19) + 9292.24952741021,
#  -1.72500000000000*sqrt(233491) - 3/2*sqrt(19) + 16252.2025000000]

# %%
def norm(x):
    return x*x.conjugate()

def is_in_ring(t, ring):
    norm = t[0]*t[0].conjugate()+t[1]*t[1].conjugate()
    if norm > ring[0] and norm < ring[1]:
        return True
    else:
        return False

def Is_in_ring(x, y, d, ring):
    for i in range(d):
        if is_in_ring([x[i],y[i]], ring) == False:
            return (i, False)
    return True

def sample_annulus(ring):
    a = ring[0]
    b = ring[1]
    T_r = RealDistribution('uniform', [sqrt(a), sqrt(b)])
    T_theta = RealDistribution('uniform', [0, 2*pi])
    
    r = T_r.get_random_element()
    theta = T_theta.get_random_element()
    x = r*cos(theta)
    y = r*sin(theta)
    
    mu = T_theta.get_random_element()
    f = abs(x)*exp(1j*mu)
    mu = T_theta.get_random_element()
    g = abs(y)*exp(1j*mu)
    
    return f,g

# %%
'''Choose Fourier representations'''
F=[]; G=[]
dd = d/2
for _ in range(dd):
    f,g = sample_annulus(new_ring)
    F.append(f)
    G.append(g)

F2 = [F[i].conjugate() for i in range(dd)]
G2 = [G[i].conjugate() for i in range(dd)]

FF = F+F2
GG = G+G2

'''Integral Fourier inverse'''
#theoretically, f,g are real but they are complex in this computation
f = ifft(FF)           
g = ifft(GG)

#rounding f to ff (closest integral vector)
ff = [round(f[i].real()) for i in range(d)]
gg = [round(g[i].real()) for i in range(d)]
f2 = ff
g2 = gg
FF2 = fft(f2)
GG2 = fft(g2)

# %%
Is_in_ring(FF2,GG2,d,[a,b])
# Out:
# (20, False)

# %%
num_exp =1000
num_suc = 0
for i in range(num_exp):
    F=[]; G=[]
    dd = d/2
    for _ in range(dd):
        f,g = sample_annulus(new_ring)
        F.append(f)
        G.append(g)

    F2 = [F[i].conjugate() for i in range(dd)]
    G2 = [G[i].conjugate() for i in range(dd)]

    FF = F+F2
    GG = G+G2

    '''Integral Fourier inverse'''
    #theoretically, f,g are real but they are complex in this computation
    f = ifft(FF)           
    g = ifft(GG)

    #rounding f to ff (closest integral vector)
    ff = [round(f[i].real()) for i in range(d)]
    gg = [round(g[i].real()) for i in range(d)]
    f2 = ff
    g2 = gg
    FF2 = fft(f2)
    GG2 = fft(g2)
    s = Is_in_ring(FF2,GG2,d,[a,b])
    print(s)
    if s == True:
        num_suc +=1
# Out:
# (5, False)
# (59, False)
# (85, False)
# (77, False)
# (33, False)
# True
# (64, False)
# (30, False)
# (19, False)
# True
# (106, False)
# (1, False)
# (38, False)
# (63, False)
# (90, False)
# (10, False)
# (94, False)
# (18, False)
# (101, False)
# (19, False)
# (20, False)
# (22, False)
# (70, False)
# True
# (4, False)
# (37, False)
# (47, False)
# (7, False)
# (24, False)
# (32, False)
# (37, False)
# True
# (64, False)
# (38, False)
# (78, False)
# (46, False)
# (120, False)
# (59, False)
# (58, False)
# (85, False)
# (46, False)
# (30, False)
# (45, False)
# (110, False)
# (94, False)
# (17, False)
# (18, False)
# (123, False)
# (32, False)
# (60, False)
# (19, False)
# (11, False)
# (42, False)
# (7, False)
# (43, False)
# (22, False)
# (24, False)
# (16, False)
# (3, False)
# (9, False)
# True
# (36, False)
# (87, False)
# (37, False)
# (96, False)
# (49, False)
# (4, False)
# (11, False)
# (108, False)
# (100, False)
# (72, False)
# (9, False)
# (84, False)
# (11, False)
# ...

# %%
num_suc
# Out:
# 783

# %%
num_suc
# Out:
# 759

# %%
num_suc #d=64, num_exp=10000
# Out:
# 7817

# %%
num_suc #d=32, num_exp=10000
# Out:
# 9189

# %%
num_suc #d=16, num_exp=10000
# Out:
# 9749

# %%
num_suc #d=64, num_exp=1000, [a,b]
# Out:
# 274

# %%
num_suc #d=128, num_exp=1000, [a,b]
# Out:
# 27

# %%
num_suc #d=128, num_exp=1000
# Out:
# 491

# %%
n = 256
d = euler_phi(n)
alpha = 1.15
q = q = 12289

def check(q,d):
    if q>pi*d/(6*(alpha-1/alpha)^2):
        return True
    else:
        return False
    
def is_in_ring(t, ring):
    norm = t[0]*t[0].conjugate()+t[1]*t[1].conjugate()
    if norm > ring[0] and norm < ring[1]:
        return True
    else:
        return False

# %%
a = 1/alpha*sqrt(q/2)
b = alpha*sqrt(q/2)
gamma = 0.94
error = sqrt(-d*ln(1-gamma)/12)

def sample_half(a,b,error):   
    D_r = RealDistribution('uniform', [a+error, b-error])
    D_theta = RealDistribution('uniform', [0, 2*pi])

    F_norm = D_r.get_random_element()
    F_theta = D_theta.get_random_element()
    F = F_norm*exp(I*F_theta)

    G_norm = D_r.get_random_element()
    G_theta = D_theta.get_random_element()
    G = G_norm*exp(I*G_theta)
    
    return F,G

def sample_simple(a,b):   
    D_r = RealDistribution('uniform', [a,b])
    D_theta = RealDistribution('uniform', [0, 2*pi])

    F_norm = D_r.get_random_element()
    F_theta = D_theta.get_random_element()
    F = F_norm*exp(I*F_theta)

    G_norm = D_r.get_random_element()
    G_theta = D_theta.get_random_element()
    G = G_norm*exp(I*G_theta)
    
    return F,G

# %%
'''Choose Fourier representations'''
u=a+error
v=b-error
F=[]; G=[]
dd = d/2
for _ in range(dd):
    f,g = sample_simple(u,v)
    F.append(f)
    G.append(g)

F2 = [F[i].conjugate() for i in range(dd)]
G2 = [G[i].conjugate() for i in range(dd)]

FF = F+F2
GG = G+G2

'''Integral Fourier inverse'''
#theoretically, f,g are real but they are complex in this computation
f = ifft(FF)           
g = ifft(GG)

#rounding f to ff (closest integral vector)
ff = [round(f[i].real()) for i in range(d)]
gg = [round(g[i].real()) for i in range(d)]
f2 = ff
g2 = gg
FF2 = fft(f2)
GG2 = fft(g2)

# %%
Is_in_ring(FF2,GG2,d,[2*a^2,2*b^2])
# Out:
# True

# %%
i=33
norm(FF2[i])+norm(GG2[i])
# Out:
# 17309.9616883075

# %%
[2*a^2,2*b^2]
# Out:
# [9292.24952741021, 16252.2025000000]

# %%
n = 1024
d = euler_phi(n)
alpha = 1.15
q = 12289

# %%
a = 1/alpha*sqrt(q/2)
b = alpha*sqrt(q/2)
gamma = 0.94
error = sqrt(-d*ln(1-gamma)/12)
aa = 2*a^2
bb = 2*b^2
u=a+error
v=b-error

# %%
num_exp =10000
num_suc = 0
for i in range(num_exp):
    '''Choose Fourier representations'''
    F=[]; G=[]
    dd = d/2
    for _ in range(dd):
        f,g = sample_simple(u,v)
        F.append(f)
        G.append(g)

    F2 = [F[i].conjugate() for i in range(dd)]
    G2 = [G[i].conjugate() for i in range(dd)]

    FF = F+F2
    GG = G+G2

    '''Integral Fourier inverse'''
    #theoretically, f,g are real but they are complex in this computation
    f = ifft(FF)           
    g = ifft(GG)

    #rounding f to ff (closest integral vector)
    ff = [round(f[i].real()) for i in range(d)]
    gg = [round(g[i].real()) for i in range(d)]
    f2 = ff
    g2 = gg
    FF2 = fft(f2)
    GG2 = fft(g2)
    
    s = Is_in_ring(FF2,GG2,d,[aa,bb])
    print(s)
    if s == True:
        num_suc +=1
# Out:
# (139, False)
# True
# True
# True
# True
# True
# (73, False)
# True
# (155, False)
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# (234, False)
# True
# (17, False)
# True
# True
# (44, False)
# True
# True
# True
# True
# True
# True
# True
# True
# (41, False)
# True
# True
# True
# True
# True
# True
# True
# (35, False)
# True
# True
# True
# (145, False)
# True
# True
# True
# True
# (177, False)
# True
# True
# True
# True
# True
# True
# True
# (253, False)
# True
# True
# True
# True
# (21, False)
# True
# True
# True
# True
# True
# (21, False)
# True
# True
# True
# (236, False)
# True
# True
# True
# True
# True
# True
# True
# (178, False)
# True
# True
# True
# (116, False)
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# (63, False)
# True
# True
# True
# True
# True
# (158, False)
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
num_suc #d=8, num_exp = 10000
# Out:
# 10000

# %%
num_suc #d=128, num_exp = 10000
# Out:
# 9729

# %%
num_suc #d=512, error= error+5
# Out:
# 8177

# %%
num_suc #d=512, error= error correct 100
# Out:
# 79

# %%
num_suc #d=512, error= error correct 1000
# Out:
# 827

# %%
num_suc #d=512, error= error correct 10000
# Out:
# 8240
